# %%
first_name='Julia'
last_name='Zhu'
full_name=first_name+' '+last_name

# %%
print(full_name)
# Out:
# Julia Zhu

# %%
Dictionary

# %%
student_marks1={"Abby":93,"Bob":95,"Chris":80}
student_marks2={s:m for s,m in [("David",1),("Ethan",2)]}

# %%
print (student_marks1)
print (student_marks2)
# Out:
# {'Abby': 93, 'Bob': 96, 'Chris': 80}
# {'David': 1, 'Ethan': 2, 'Fiona': 88}

# %%
student_marks1["Bob"]=96
student_marks2["Fiona"]=88

# %%
print(student_marks1["Abby"])
# Out:
# 93

# %%
"David" in student_marks2
# Out:
# True

# %%
("David",1) in student_marks2.items()
# Out:
# True

# %%
[i for i in student_marks1]
student_marks1.keys()
[i for i in student_marks1.values()]
[i for i in student_marks1.items()]
# Out:
# [('Abby', 93), ('Bob', 96), ('Chris', 80)]

# %%
ordered = OrderedDict([("David",1),("Ethan",2)])

# %%
#Assume we are working with a dictionary whose values are all unique numbers. 
#Write a function that returns the key that maps to the largest value in the dictionary.
d={"Abby": 93,"Bob": 95,"Chris": 80,'David': 1, 'Ethan': 2, 'Fiona': 88}

# %%
def max_key(x):
    maxV=max(x.values())
    for key,value in x:
        if value==maxV: 
            return key
        
print(max_key(d))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5309a8a92f01> in <module>
#       6             return key
#       7
# ----> 8 print(max_key(d))
#
# <ipython-input-15-5309a8a92f01> in max_key(x)
#       2 def max_key(x):
#       3     maxV=max(x.values())
# ----> 4     for key,value in x:
#       5         if value==maxV:
#       6             return key
#
# ValueError: too many values to unpack (expected 2)

# %%
def max_key_optimal(x):
    return max(x, key=x.get)
print(max_key_optimal(d))
# Out:
# Bob

# %%
numbers=[1,2,3]
words=['one','two','three']
letters=['a','b','c']
print(list(zip(numbers,words,letters)))
# Out:
# [(1, 'one', 'a'), (2, 'two', 'b'), (3, 'three', 'c')]

# %%
SETS

# %%
x={i**2 for i in range(7) if i != 3}

# %%
set()
# Out:
# set()

# %%
#Use a set to find all of the unique letters in the string "The cat in the hat". 
#Ignore all non-letter characters and lowercase all letters.
# Out:
#   File "<ipython-input-29-e7e4718702c1>", line 1
#     Use a set to find all of the unique letters in the string "The cat in the hat".
#         ^
# SyntaxError: invalid syntax

# %%
word="The cat in the hat"
{i.lower() for i in word if i.isalpha()}
# Out:
# {'a', 'c', 'e', 'h', 'i', 'n', 't'}

# %%
x.update([1, 2, 3])
print(x)
# Out:
# {0, 1, 2, 3, 4, 36, 16, 25}

# %%
frozenset({1, 2, 3})

# %%
class Pizza():
    ""Represent a pizza"
    
    def __init__(self,dough,shape):
        self.base=dough
        self.shape=shape
        self.cooked=False
        
    def bake(self):
        ""Bake pizza"
        self.cooked=True
        print("Pizza is ready.")
        
    def getStatus(self):
        
        
class CheesePizza(Pizza):
    ""Represent a pizza"
    
    def __init__(self,dough,shape):
        super.__init__(dough,shape)
        self.extraCheese=0
        
    def addCheese(num):
        ""Add num kg of cheese to pizza.""
        self.extraCheese+=num
