# %%
import pandas as pd

# %%
ser1=pd.Series(data=[1,2,3,4,5],index=list("abcde"))
ser1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# #

# %%
ser2=pd.Series(data=[11,12,13,14,15],index=list("abcde"))
ser2
# Out:
# a    11
# b    12
# c    13
# d    14
# e    15
# dtype: int64

# %%
d=pd.DataFrame("->":ser1,"<-":ser2)
# Out:
#   File "<ipython-input-16-11b27b8c50a7>", line 1
#     d=pd.DataFrame("->":ser1,"<-":ser2)
#                        ^
# SyntaxError: invalid syntax

# %%
import mathplotlib.pyplot as py
